# %%
# Auto_plume_ID.ipynb

# This is the first programme of SOFT-IO-LI and it searches the IAGOS database for new NOx (IAGOS CORE) or NO and NO2 (CARIBIC)
# flights to analyse. A check is made to ensure the PV variable is included in the dataset, if not it is added.
# It searches for excess NOx (NO + NO2) above the 75th percentile of the NOx measured during the flight and identifies NOx plumes.
# It selects the plumes if they are measured during the cruise phase of the flight, if there are no stratospheric influences 
# (PV > 2 K m2 kg-1 s-1 and if the CO and O3 are below 100 ppb.
# Short plumes (<12km) are removed as most probably being from aviation emissions.
# The plume information, arrival date and times required for FLEXPART are extracted and saved and plots are made of the remaining plumes
# to enable checks to be easily made.

# C. Mackay September 2022 (Catherine.Mackay@aero.obs-mip.fr)
# https://github.com/ckmackay/SOFT-IO-LI.git

#Suggestions/improvements to be made:

# function find_untested_NOx_flights()
# Once NOx lightning data is added to the IAGOS db we need to include a check so as not to reanalyse any flights.

# function apply_cuts()
# CO and O3 cut at 100 ppb, this could be changed to 75th percentile of CO/O3 in that region, that month. Code to calculate these is in github.
# A quick check did not see any obvious improvment in doing this.

# %%
import numpy as np
import pandas as pd
import xarray as xr
import json

import os

#for plotting
import matplotlib.pyplot as plt

#for datetime
import datetime
from datetime import datetime as dt
import matplotlib.dates as mdates
from matplotlib.dates import date2num

# %%
### Check the following paths and settings: these are set for SOFT-IO-LI default on nuwa in /o3p/iagos/SOFT-IO-LI
### For testing, think of creating /o3p/user/SOFT-IO-LI/ and changing the paths below. 
### you will need to create the following directories:
### /o3p/user/SOFT-IO-LI/FLEXPART_templates
### /o3p/iagos/SOFT-IO-LI/Plume_info_all_cuts/
### /o3p/iagos/SOFT-IO-LI/flight_time_txt/

def set_paths():
    
    global iagos_cat, PV_path, plume_info_path, plume_plots_path, flight_time_path
    
    iagos_cat = '/o3p/iagos/catalogues/'
    PV_path='/o3p/iagos/L4/L2-ECMWF-PV-CO_contributions/'
    
    ### change for your user name!!!
    
    plume_info_path = '/o3p/macc/SOFT-IO-LI/Plume_info_all_cuts/'
    plume_plots_path = '/o3p/macc/SOFT-IO-LI/plots/'
    flight_time_path = '/o3p/macc/SOFT-IO-LI/flight_time_txt/'

# %%
# Search for NOx flights
# Using the catalogues search for any flights with NOx measurements
# Make a list of their locations
# Return the number of flights found

### Nb. Once NOx lightning data is added to the db we need to include a check so as not to reanalyse any flights

def find_untested_NOx_flights():
    global flights_with_NOx, df
    #df = pd.read_hdf('/o3p/wolp/catalogues/iagos.h5', key='sources')
    df = pd.read_hdf(iagos_cat+'iagos_L2.h5', key='sources')
    #novars = [c for c in df if c.startswith("data_vars_") and ("NOx") in c] #selects only IAGOS-CORE flights (210 in total)
    novars = [c for c in df if c.startswith("data_vars_") and ("NO2") in c] #selects IAGOS-CORE & IAGOS-CARIBIC flights (669 in total)

    flights_with_NOx = df.loc[(df[novars] > 0).any(axis="columns")]
    #print(novars)
    print(len(flights_with_NOx), 'flights containing NOx measurements')
    
    return

# %%
# Set paths & fetch the NOx flight information

set_paths()
find_untested_NOx_flights()
# Out:
# 669 flights containing NOx measurements

# %%
#Check the list, optional
#flights_with_NOx

# %%
# Main programme, takes each flight and analyses, saving data necessary for FLEXPART if plumes are identified.

def provide_flight_info(flights_with_NOx):

    global flight_no
    
    flight_no=0
    for i in range(len(flights_with_NOx)):
         
        #set global vairables
        global ds
        global NOx_anom
        
        flights_with_NOx.drivers_load_args.iloc[i]
        ds = xr.load_dataset(*json.loads(flights_with_NOx.drivers_load_args.iloc[i])["args"])
        
        # Only use cruise information
        ds['data_vars_cruise'] = xr.where(ds["air_press_AC"]<30000, True, False)
        ds
        
        
        
        flight_no=flight_no+1
    
    # check if flight is CORE or CARIBIC and then select O3 and CO accordingly
    
        global val_data_NOx
        global data_PV
        if ds.source=='IAGOS-CORE':
            IAGOS_CORE()
        elif ds.source=="IAGOS-CARIBIC": #need to complete this§§§
            IAGOS_CARIBIC()
        else:
            print("Warning - flight source is neither IAGOS-CORE nor IAGOS-CARIBIC - Error!")
            
        global t, lon, lat
        t=ds.UTC_time.where(ds.data_vars_cruise==True)
        lon=ds.lon.where(ds.data_vars_cruise==True)
        lat=ds.lat.where(ds.data_vars_cruise==True)
   
        
        #if 'PV' in list(ds.keys()) and np.all(np.isnan(val_data_NOx)):
        
        if np.all(np.isnan(val_data_NO)):
            #If all NOx values are nan, move to next flight after giving a warning
            print('WARNING: NO all nan values in flight: ',ds.attrs['flight_name'], ', moving to next flight')
            
        elif np.all(np.isnan(val_data_NO2)):
            #If all NOx values are nan, move to next flight after giving a warning
            print('WARNING: NO2 all nan values in flight: ',ds.attrs['flight_name'], ', moving to next flight')
        
        elif np.all(np.isnan(val_data_NOx)):
            #If all NOx values are nan, move to next flight after giving a warning
            print('WARNING: NOx all nan values in flight: ',ds.attrs['flight_name'], ', moving to next flight')
            
            
        #Check if the txt file already exisits...if so print warning and move to next flight
        #elif 'PV' in list(ds.keys()) and os.path.exists('Plume_info_'+ds.attrs['flight_name']+'.txt'):
        
        elif os.path.exists(plume_info_path+'Plume_info_'+ds.attrs['flight_name']+'.txt'):
            print('*******************************************')
            print('WARNING: Plume_info_',ds.attrs['flight_name'], ', already exisits, moving to next flight')
            print('*******************************************')
            
        #Otherwise analyse the flight data
        #elif 'PV' in list(ds.keys()):
        else:    
            print('ANALYSING flight: ',ds.attrs['flight_name'])
            print('*******************************************')
            
            print("***Applying cuts***")
            apply_cuts()
            
            print("***Calculating moving averages***")
            calculate_moving_average(NOx_anom)
            
            print("***Finding plumes***")
            find_plumes(NOx_anom)
            
            print("***Removing planes***")
            remove_plane()
            
            
            if len(list1)==len(list2):
                print(len(list1), "plume(s) identified")
                #print("list1&2",list1, list2)
                #Now obtain the info on each plume and write this to the approproate txt file in ../Plume_info
                #also check for num_list
                
            
            
                #if len(list1)>0:
                if len(plume_start)>0:
                    print("***Plot plumes***")
                    plot_plumes()
                    print("***Extract datetime info***")
                    extract_datetime()
                    print("***Writing plume info***")
                    write_plume_info()
                else:
                    print("No plumes identified, end of anaylsis for this flight")
          
                
                
                
                
            else:
                print("No plumes identified, end of anaylsis for this flight")
          
        #else:
            #print('WARNING: No PV data available in flight: ',ds.attrs['flight_name'], ', moving to next flight')
            
    return(ds)

# %%
# Obtain IAGOS CORE flight variables, check if PV is included in the datasets, if not add it from L4 data

def IAGOS_CORE():
            
    print('*******************************************')
    print('IAGOS-CORE', flight_no)
    print('*******************************************')
    
    global val_data_NO, val_data_NO2, val_data_NOx
    global data_PV, val_data_CO, val_data_O3
    
    # Only select CO data where data quality flag is good (=0)
    ds['data_status_CO'] = xr.where(ds["CO_P1_val"]==0, True, False)
    # Only select O3 data where data quality flag is good (=0)
    ds['data_status_O3'] = xr.where(ds["O3_P1_val"]==0, True, False)
    # Only select NOx data where data quality flag is good (=0)
    ds['data_status_NO'] = xr.where(ds["NO_P2b_val"]==0, True, False)
    ds['data_status_NO2'] = xr.where(ds["NO2_P2b_val"]==0, True, False)
        
    ### If 2018 onwards
    ds['data_status_NOx'] = xr.where(ds["NOx_P2b_val"]==0, True, False)
    # NOx_P2b_val==7 points where no data was collected so may have been an excess
    ds['data_status_NOx_null'] = xr.where(ds["NOx_P2b_val"]==7, True, False) 
        
    data_O3 = ds.O3_P1.where(ds.data_vars_cruise==True)
    val_data_O3 = data_O3.where(ds.data_status_O3==True)
    #mean_O3 = np.mean(data_O3)
    #print(mean_O3)
    data_CO = ds.CO_P1.where(ds.data_vars_cruise==True)
    val_data_CO = data_CO.where(ds.data_status_CO==True)
            
    #check if PV is included in the db (it isn't for lots of flights in 2005)using check_PV
    #if not check_PV calls function add_PV
    #Probably not needed for CORE but if new entries in DB this might be missing initially
            
    check_PV()
            
    data_PV = ds.PV.where(ds.data_vars_cruise==True)
    data_PV = 100*data_PV #100*PV used so it can be plotted on the same plot
    data_NO = ds.NO_P2b.where(ds.data_vars_cruise==True)
    val_data_NO =  data_NO.where(ds.data_status_NO==True)
    data_NO2 = ds.NO2_P2b.where(ds.data_vars_cruise==True)
    val_data_NO2 = data_NO2.where(ds.data_status_NO2==True)
    data_NOx = ds.NOx_P2b.where(ds.data_vars_cruise==True)
    val_data_NOx = data_NOx.where(ds.data_status_NOx==True)
    no_val_data_NOx = data_NOx.where(ds.data_status_NOx_null==True)
    mean_NOx = np.nanmean(data_NOx)
            
    # cloud info
    data_cloud = ds.cloud_P1.where(ds.data_vars_cruise==True) # add cloud data
    data_cl = ds.cloud_presence_P1.where(ds.data_vars_cruise==True) # add cloud data

# %%
# Obtain IAGOS Caribic variables, check if PV is included in the datasets, if not add it from L4 data

def IAGOS_CARIBIC():
    
    print('*******************************************')
    print('IAGOS-CARIBIC', flight_no)
    print('*******************************************')
     
    global val_data_NO, val_data_NO2, val_data_NOx
    global data_PV, val_data_CO, val_data_O3
    
    data_O3 = ds.O3_PC2.where(ds.data_vars_cruise==True)
    data_CO = ds.CO_PC2.where(ds.data_vars_cruise==True)
    data_NO = ds.NO_PC2.where(ds.data_vars_cruise==True)
    data_NO2 = ds.NO2_PC2.where(ds.data_vars_cruise==True)
    data_NOy = ds.NOy_PC2.where(ds.data_vars_cruise==True)
    #data_NOx = data_NO + data_NO2
            
    # Only select CO data where data quality flag is good (=0)
    ds['data_status_CO'] = xr.where(ds["CO_PC2_val"]==0, True, False)
    # Only select O3 data where data quality flag is good (=0)
    ds['data_status_O3'] = xr.where(ds["O3_PC2_val"]==0, True, False)
    # Only select NOx data where data quality flag is good (=0)
    ds['data_status_NO'] = xr.where(ds["NO_PC2_val"]==0, True, False)
    ds['data_status_NO2'] = xr.where(ds["NO2_PC2_val"]==0, True, False)
            
    data_O3 = ds.O3_PC2.where(ds.data_vars_cruise==True)
    val_data_O3 = data_O3.where(ds.data_status_O3==True)
    #mean_O3 = np.mean(data_O3)
    #print(mean_O3)
    data_CO = ds.CO_PC2.where(ds.data_vars_cruise==True)
    val_data_CO = data_CO.where(ds.data_status_CO==True)
            
    #check if PV is included in the db (it isn't for lots of flights in 2005)using check_PV
    #if not check_PV calls function add_PV
            
    check_PV()
            
    #Some L2 files don't include PV either, so run a second check to see if they've been added, if not break
            
    if 'PV' in list(ds.keys()):
                
        data_PV = ds.PV.where(ds.data_vars_cruise==True)
        data_PV = 100*data_PV #100*PV used so it can be plotted on the same plot
        data_NO = ds.NO_PC2.where(ds.data_vars_cruise==True)
        val_data_NO =  data_NO.where(ds.data_status_NO==True)
        data_NO2 = ds.NO2_PC2.where(ds.data_vars_cruise==True)
        val_data_NO2 = data_NO2.where(ds.data_status_NO2==True)
        #data_NOx = ds.NOx_PC2.where(ds.data_vars_cruise==True)
        #val_data_NOx = data_NOx.where(ds.data_status_NOx==True)
                
        if np.all(np.isnan(val_data_NO)):
            print("***No NO recorded in this flight")
        elif np.all(np.isnan(val_data_NO2)):
            print("***No NO2 recorded in this flight")
        else:
            data_NOx = data_NO+data_NO2
            val_data_NOx = val_data_NO+val_data_NO2
                    
            #no_val_data_NOx = data_NOx.where(ds.data_status_NOx_null==True)
            mean_NO = np.nanmean(val_data_NO)
            mean_NO2 = np.nanmean(val_data_NO2)
            mean_NOx = np.nanmean(val_data_NOx)
            
            print("***mean_NO = ", mean_NO, "***")
            print("***mean_NO2 = ", mean_NO2, "***")
            print("***mean_NOx = ", mean_NOx, "***")
            
        # cloud info not available for CARIBIC flights
        
        #data_cloud = ds.cloud_P1.where(ds.data_vars_cruise==True) # add cloud data
        #data_cl = ds.cloud_presence_P1.where(ds.data_vars_cruise==True) # add cloud data
        #data_temp = ds.air_temp_AC.where(ds.data_vars_cruise==True) # add cloud data
    else:
        pass

# %%
# Function to check if the PV is saved in the DB. Often this is not the case for CARIBIC flights
# If it's missing call function add_PV to add the PV to the dataset ds

def check_PV():
    if 'PV' in list(ds.keys()):
        pass
    else:
        add_PV()

# %%
# Function to add PV to dataset if it's missing. PV is saved in /o3p/iagos/iagosv2/netcdf/L2/XXXXYY 
# where XXXX = year and YY month
# Code extracts correct year and month to find the correct L2 or L4 information.
# Once it's found the correct flight data file it compares the length of the flight to ensure it's the correct one.
# Then it adds the PV data to the dataset.
# Otherwise it prints and error message.

def add_PV():
    #find correct directory for flight
    start_datetime=(ds.departure_UTC_time)
    date_time = start_datetime.split("T")
    date = date_time[0]
    #print(start_datetime)
    #print(date)
    date_split = date.split("-")
    yr=date_split[0]
    #print(yr)
    mnth=date_split[1]
    #print(mnth)
    
    #find correct file for flight
    file_name = 'IAGOS_'+ds.flight_name+'_L4.nc'
    
    dr = xr.open_dataset(PV_path+yr+mnth+'/'+file_name)
    
    #Add PV to dataset ds
    
    #print(ds.UTC_time)
    time = ds.UTC_time
    last_time = (len(ds.UTC_time)-1)
    #print(last_time)
    #print("final time =", time[0])
    #print("final time =", time[int(last_time)])
    
    time_PV = dr.UTC_time
    last_time_PV = (len(dr.UTC_time)-1)
    
    #print(time_PV, last_time_PV)
    
    #check time lengths agree, if so add PV to dataset ds
    # ds is L1, dr = L4
    
    if len(ds.UTC_time)==len(dr.UTC_time):
        #print("No problems with time lengths")
        ds["PV"]=(['UTC_time'],  dr.PV)
    else:
        print("ERROR: PROBLEM WITH TIME LENGTHS!!!")
        #print(len(ds.UTC_time))
        #print(len(UTC_time_secs))
    
    
    if 'PV' in list(dr.keys()):
        #print("found PV")
        pass
    else:
        print("PV missing in L4 dataset")
        pass

# %%
# Apply cuts: applies the following cuts on the flight data.
# NOx 75th percentile
# PV > 2 K m2 kg-1 s-1
# CO > 100 ppb
# O3 > 100 ppb
# returns the data that passes this data selection.

def apply_cuts():
    global NOx_anom
    global cl75
    # Find mean, 75th percentile and 95th percentile of good quality NOx data in cruise

        #data = data_NOx.where(ds.data_status_NOx==True)
        #clim = data.mean()

    clim = val_data_NOx.mean()
        #print(len(val_data_NOx))
        #print('1000 = ', val_data_NOx[100])
    #print('clim = ',clim)
        
            #find 75 percentile
    cl75 = np.nanpercentile(val_data_NOx, 75)
            #print('75th percentile', cl75)
        #find 95 percentile
    cl95 = np.nanpercentile(val_data_NOx, 95)
            #print('95th percentile', cl95)
            
    #print("Mean NOx", clim.values)
    print("Mean NOx", clim)
    
    print("75th percentile NOx", cl75)
    #print("95th percentile NOx", cl95)

    NOx_anom = val_data_NOx - cl75
            
            #ds['NOx_anom'] = val_data_NOx - cl75
            
    NOx_anom = NOx_anom.where(NOx_anom>=0) #Only keep positive values
            
    NOx_anom = NOx_anom.where(data_PV<200) #this value is fixed (NB PV is multiplied by 100, so actually cutting at 2!!!)
    
    NOx_anom = NOx_anom.where(val_data_O3<110) #this value is fixed
    NOx_anom = NOx_anom.where(val_data_CO<110) #this value is fixed

# %%
# Write plume info to txt file
# This txt files contains the information that FLEXPART_auto.ipynb requires to produce the FLEXPART control files.

def write_plume_info():
    num_list=[]
    for i in range (len(plume_end)):
        num_list.append("plume_"+str(i+1))
    #rint(num_list)
    
    plume_info=[[len(plume_end)]]
    temp=[[]] * len(num_list)
    
    for i in range(len(num_list)):
        ts = pd.to_datetime(str(ds.UTC_time[plume_start[i]].values))
        date_start = ts.strftime('%Y%m%d')
        time_start = ts.strftime('%H%M%S')
        te = pd.to_datetime(str(ds.UTC_time[plume_end[i]].values))
        date_end = te.strftime('%Y%m%d')
        time_end = te.strftime('%H%M%S')
        #print(i, plume_start[i], plume_end[i], date_start, date_end, time_start, time_end,
        ds.lon[plume_start[i]].values, ds.lon[plume_end[i]].values 
        ds.lat[plume_start[i]].values, ds.lat[plume_end[i]].values
        ds.air_press_AC[plume_start[i]].values, ds.air_press_AC[plume_end[i]].values
        ds.baro_alt_AC[plume_start[i]].values, ds.baro_alt_AC[plume_end[i]].values
        
        temp[i]= plume_start[i], plume_end[i], int(date_start), int(date_end), int(time_start), int(time_end), float(ds.lon[plume_start[i]].values), float(ds.lon[plume_end[i]].values), float(ds.lat[plume_start[i]].values), float(ds.lat[plume_end[i]].values), float(ds.air_press_AC[plume_start[i]].values), float(ds.air_press_AC[plume_end[i]].values),float(ds.baro_alt_AC[plume_start[i]].values), float(ds.baro_alt_AC[plume_end[i]].values)
        
    np.savetxt(plume_info_path+'Plume_info_'+ds.attrs['flight_name']+'.txt',temp, fmt=' '.join(['%i']*4 + ['%06d']*2 + ['%1.4f']*8))

# %%
# Finds new_start for each plume

def new_starts(new_start, NOx_anom):
    plume_start_id = []
    #print(new_start)
    count = new_start
    eof = len(NOx_anom)
    #for i in range(new_start,eof):
    for i in range(count,eof):
    
        count += 1
        if NOx_anom[i]>0:
            #plume_start_id = [count-1]
            plume_start_id.append(count-1)
            plume_start_lon = [lon[i].values]
            plume_start_NOx = [NOx_anom[i].values]
            break
    #print("plume_start_id =", plume_start_id)
    return(plume_start_id)

# %%
# Finds new_end for each plume - using the moving average caluculated by mov_ave_NOx_anom 

def new_end(new_end, total_NOx):
    #global total_NOx
    #print(new_end)
    count = new_end 
    count_b=0
    for i in range(new_end,len(mov_ave_NOx_anom)):
        count +=1
        plume_end_id = [count-51]
        plume_end_lon = [lon[i-51].values]
        plume_end_NOx = [mov_ave_NOx_anom[i-50]]
        old_total = total_NOx
        total_NOx = total_NOx + np.nansum(mov_ave_NOx_anom[i])
        if old_total == total_NOx:
            count_b +=1
        else: count_b =0
        if count_b ==50: #60 if unchanged for 4 mins assume end of plume....OK for first plume
            break
            
    return(plume_end_id, total_NOx)

# %%
# Finds the plumes that meet the criteria

def find_plumes(NOx_anom):
    global start
    global plume_end_id
    global plume_start_id
    global list1, list2
    # Start search from 0
    n_start = 0
    counter = [0, 1]
    list1 = []
    list2 = []
    
    while counter[-1] > counter[-2]:
        #print(nstart)
        counts = counter[-1]
        #print("counts", counts)
        #print("nstart= ", n_start, "start= ", start)
        #list1.append(n_start)
    
        plume_start_id = new_starts(n_start, NOx_anom)
        #print("Value of start of first plume = ", plume_start_id)
        #got start of first plume
        #take new start from last value in plume_end_id
        plume_start_id_len = len(plume_start_id)-1
        #print(plume_start_id_len)
        
        if len(plume_start_id)==0:
            
            counter = [0, 0]
            
            
        else:
            for index, x in enumerate(plume_start_id):
                
                if index == plume_start_id_len:
            
                    start = plume_start_id[index]
                #print("Start value = ", start)
                    list1.append(start)
            plume_end_id = new_end(start, 0)[0]
        #print("Check", plume_end_id)
            total_NOx = new_end(start, 0)[1]
        #print("Value of end of first plume = ", plume_end_id)
            plume_end_id_len = len(plume_end_id)-1
        #print("plume_end_id", plume_end_id)
            for index, x in enumerate(plume_end_id):
                if index == plume_end_id_len:
                    n_start = plume_end_id[index]
        #print("what goes in to list2", n_start)
            list2.append(n_start)
            if len(list2)>=2:
                if list2[-1]==list2[-2]:
                    del list2[-1]
                    break
            n_start = n_start+1 
    
        #print("New starting point", n_start) 
        #print("nstart= ", n_start, "start= ", start)
            if n_start>start:
                counts+=1
            #print(counts)
                counter.append(counts)
            #print(counter)
        #print('Total NOx measured', total_NOx) 
        #print('list1 =', list1)
        #print('list2 =', list2)

# %%
# Removes small plumes, usually high NOx values, that are associated with aviation emissions

def remove_plane():
    global plume_start, plume_end
    plume_start=[]
    plume_end=[]
    for i in range (len(list1)):
        #print("Diff = ", i, (list2[i])-(list1[i]))
        if (list2[i])-(list1[i])>= 15: #removes plumes of less than 12-15km extent as most likely to be related to aircraft emissions
            #keep pair
            plume_start.append(list1[i])
            plume_end.append(list2[i])
        
                        #del(list2[i])
                        #del(list1[i])
    
                #print(rem)       
    #del list2
    #del list1
    #print("plume st in remove plane=", plume_start)
    #print("plume en in remove plane=", plume_end)
        #else:
         #   counter[-1] == counter[-2]
            #pass

# %%
# Calculate the moving average of NOx_anom

def calculate_moving_average(NOx_anom):
    global mov_ave_NOx_anom

    #Calculate moving average
    window_size = 50
    i = 0
    count = []
    mov_ave_NOx_anom = []
    while i < len(NOx_anom) - window_size + 1:
        #if NOx_anom[i]>=0:
        this_window = NOx_anom[i : i + window_size]
        #window_average = sum((this_window) / window_size, skipna=True)
        window_average = np.nansum(this_window) / window_size
        mov_ave_NOx_anom.append(window_average)
        #print(window_average)
        count.append(i)
        #print(i)
        i += 1
        j = 0    
        while j < window_size -1:
        #    #print(j)
        #    mov_ave_NOx_anom.append(None)
            j+=1

    #print(mov_ave_NOx_anom)

# %%
# Plot the plume information for checking

def plot_plumes():
    params = {'legend.fontsize': 'x-large',
              'figure.figsize': (20, 5),
             'axes.labelsize': 'x-large',
             'axes.titlesize':'x-large',
             'xtick.labelsize':'x-large',
             'ytick.labelsize':'x-large'}
    plt.rcParams.update(params)
    
    lon_min = np.nanmin(lon)
    lon_min = lon_min-5
    print("lon_min",lon_min)
    lon_max = np.nanmax(lon)
    lon_max=lon_max+5
    print("lon_max",lon_max)
    fig, ax1 = plt.subplots()
    ax1.set_xlim([lon_min, lon_max])
    color = 'tab:red'
    ax1.set_ylabel('O3 & CO (ppb)')
    ax1.plot(lon, val_data_O3, color=color, label='O3')
    ax1.plot(lon, val_data_CO, color='tab:orange', label='CO')
    ax1.plot(lon, ds.PV*100, color='tab:grey', label='PV*100')
    ax1.tick_params(axis='y', labelcolor=color)
    

    ax1.set_ylim([0, 200]) #Only plot troposphere
    plt.axhline(y=100, linestyle='--', color='tab:orange') #assuming CO background of 100 ppbv

    ax1.set_xlabel('Longitude (°)')
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('NO, NO2 & NOx (ppb)')  # we already handled the x-label with ax1
    ax2.plot(lon, val_data_NO, color=color, label='NO')
    ax2.plot(lon, val_data_NO2, color='tab:green', label='NO2')
#if ds.source=='IAGOS-CORE':
    ax2.plot(lon, val_data_NOx, color= 'tab:purple', label='NOx')
    ax2.plot(lon, NOx_anom, color= 'tab:pink', label='NOx plumes')
    plt.axhline(y=cl75, linestyle='--', color='tab:orange')
  
    fig, ax1 = plt.subplots()
    ax1.set_xlim([lon_min, lon_max])
    ax1.set_xlabel('Longitude (°)')
    ax1.set_ylabel('NOx plumes (ppb)')
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('Not used')  # we already handled the x-label with ax1
    
    #ax1.set_xlim([lon_min, lon_max])
    
    ax1.plot(lon, NOx_anom, color= 'tab:pink', label='NOx plumes')
    
    for i in range(len(plume_start)):
        plt.axvline(x=plume_start[i])
        plt.axvline(x=plume_end[i])
    
    plt.savefig(plume_plots_path+ds.attrs['flight_name']+'.png')
    plt.show()
    plt.clf()

# %%
# Extract date and time information of flight arrival for FLEXPART AVAILABLE file and save to flight_time_txt/ directory.

def extract_datetime():
    
    date = ds.arrival_UTC_time.split('T')[0]
    time = ds.arrival_UTC_time.split('T')[1]

    #print(date)
    #print(time)
    
    year = date.split('-')[0]
    month = date.split('-')[1]
    day = date.split('-')[2]
    hour = time.split(':')[0]
    #print("year = ", year, ", month = ",month, ", day = ",day, "hour = ", hour)
    
    dt=(str(year), str(month), str(day), str(hour))

    trial=[dt]
    #print('dt=', trial)
    np.savetxt(flight_time_path+'Plume_info_'+ds.attrs['flight_name']+'.txt',trial,fmt=' '.join(['%s']))

# %%
# Run the provide_flight_info to find and isolate plumes

provide_flight_info(flights_with_NOx)
# Out:
# *******************************************
# IAGOS-CARIBIC 1
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005051920261591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 2
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005052009010591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 3
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005052012311591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 4
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005052016094591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 5
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005062021072591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 6
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005062110235591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 7
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005062116280591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 8
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005062121113591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 9
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005072721015591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 10
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005072810260591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 11
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005072816163591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 12
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005072821042591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 13
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005083020521591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 14
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005083110152591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 15
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005083116132591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 16
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005083120594591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 17
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005100421265591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 18
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005100510320591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 19
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005100516141591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 20
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005100522001591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 21
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005111420565591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 22
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005111509423591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 23
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005111513125591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 24
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005111516391591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 25
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005121422031591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 26
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005121511163591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 27
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2005121517082591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 28
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2005121521485591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 29
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006022021465591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 30
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006022111091591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 31
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006022116583591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 32
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006022121512591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 33
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006032022005591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 34
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006032111214591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 35
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006032117073591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 36
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006032121501591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 37
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006042720430591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 38
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006042808302591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 39
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006042811575591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 40
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006042815415591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 41
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006052920575591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 42
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006053008264591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 43
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006053012031591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 44
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006053015300591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 45
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006070520375591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 46
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006070608144591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 47
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006070611591591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 48
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006070615225591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 49
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006073120532591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 50
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006080108315591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 51
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006080112100591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 52
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006080115372591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 53
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006090720565591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 54
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006090808285591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 55
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006090812011591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 56
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006090815351591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 57
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006101920475591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 58
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006102008324591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 59
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006102012055591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 60
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006102015412591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 61
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006111422031591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 62
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006111509304591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 63
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006111513092591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 64
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006111516372591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 65
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2006121322440591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 66
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006121410173591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 67
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006121413555591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 68
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2006121417043591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 69
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007020521315591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 70
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007020609255591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 71
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007020613034591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 72
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007020616320591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 73
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007030621515591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 74
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007030709292591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 75
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007030713042591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 76
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007030716361591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 77
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007041820591591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 78
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007041912211591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 79
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007041916210591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 80
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007041919315591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 81
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007052221351591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 82
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007052310193591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 83
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007052313363591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 84
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007052316514591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 85
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007062121524591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 86
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007062210233591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 87
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007062213361591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 88
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007062217104591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 89
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007071721114591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 90
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007071809575591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 91
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007071813334591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 92
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007071816581591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 93
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007081421080591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 94
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007081509393591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 95
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007081513505591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 96
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007081517065591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 97
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007091711470591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 98
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007091722083591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 99
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007091808154591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 100
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007091820394591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 101
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007102421153591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 102
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007102510053591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 103
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007102513352591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 104
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007102517115591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 105
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007111322050591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 106
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007111409313591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 107
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2007111413153591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 108
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007121713194591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 109
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2007121801154591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 110
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008022521515591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 111
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008022609185591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 112
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008022613250591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 113
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008022616454591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 114
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008032621470591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 115
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008032709382591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 116
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008032713092591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 117
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008032717085591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 118
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008042309161591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 119
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008042320303591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 120
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008042409213591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 121
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008042420331591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 122
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008052809201591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 123
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008052820211591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 124
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008052909281591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 125
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008052920470591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 126
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008061809361591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 127
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008061820405591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 128
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008061909242591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 129
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008061920373591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 130
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008071509395591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 131
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008071522092591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 132
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008071611571591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 133
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008071700292591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 134
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008081309323591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 135
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008081321315591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 136
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008081409262591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 137
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008081421212591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 138
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008091009204591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 139
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008091020494591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 140
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008091109282591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 141
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008091120345591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 142
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008101509332591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 143
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008101520424591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 144
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008111410164591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 145
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008111420541591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 146
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008111509535591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 147
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008111523242591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 148
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008121109382591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 149
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008121120482591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 150
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2008121210441591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 151
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2008121221330591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 152
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2009031022200591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 153
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2009031117150591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 154
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2009031213234591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 155
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2009031302131591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 156
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009042209515591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 157
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009042223004591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 158
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009042312331591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 159
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009042400074591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 160
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009052612101591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 161
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009052700224591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 162
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009052713041591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 163
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009052802441591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 164
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009062311203591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 165
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009062323100591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 166
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009072210083591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 167
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009072300461591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 168
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009072312262591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 169
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009072323562591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 170
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009082610130591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 171
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009082623140591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 172
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009082712324591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 173
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009082800014591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 174
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009092310132591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 175
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009092322044591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 176
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009092411575591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 177
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009092500022591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 178
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009102722104591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 179
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2009102816531591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 180
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2009102910134591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 181
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2009102922312591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 182
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010042013494591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 183
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010051608104591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 184
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010051907444591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 185
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010062209531591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 186
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010062221480591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 187
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010062312323591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 188
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010062401493591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 189
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010072709550591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 190
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010072722115591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 191
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010072812243591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 192
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010072901101591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 193
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010082510104591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 194
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010082523104591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 195
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010082612321591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 196
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010082701245591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 197
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010092210161591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 198
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010092222123591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 199
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010092312232591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 200
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010092401055591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 201
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010102010413591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 202
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010102022462591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 203
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010102112424591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 204
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010102201105591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 205
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010111423100591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 206
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010111615112591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 207
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010121222065591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 208
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2010121317215591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 209
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010121414192591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 210
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2010121503584591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 211
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2011011821553591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 212
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2011011918284591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 213
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2011012013135591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 214
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2011012103104591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 215
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2011022422341591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 216
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2011022517260591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 217
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2011022613331591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 218
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2011022702385591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 219
# *******************************************
# ...
# WARNING: NO2 all nan values in flight:  2013091823452591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 319
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2013091911502591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 320
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2013091923584591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 321
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2013101711435591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 322
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013101723503591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 323
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2013110717114591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 324
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013110806152591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 325
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013110821314591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 326
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013110909311591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 327
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013110913292591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 328
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013110918002591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 329
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2013120317144591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 330
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013120406144591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 331
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2013120421230591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 332
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013120509391591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 333
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013120513263591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 334
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2013120517073591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 335
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2014011616590591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 336
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014011706273591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 337
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2014011721242591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 338
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014011809320591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 339
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014011813173591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 340
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014011817075591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 341
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2014021317114591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 342
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014021406163591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 343
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014021723551591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 344
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014040713105591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 345
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014040802061591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 346
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014040815583591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 347
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014040905250591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 348
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014081914380591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 349
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014082004170591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 350
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014082020324591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 351
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014082120043591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 352
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014092314562591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 353
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014092405184591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 354
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014092420455591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 355
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014092520131591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 356
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014102915335591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 357
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014103004100591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 358
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014103018503591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 359
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014103106241591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 360
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014112515133591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 361
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014112605262591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 362
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014112621365591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 363
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014112711340591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 364
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2014112721180591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 365
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015011315060591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 366
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015011405120591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 367
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015011421444591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 368
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015011521152591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 369
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015020915422591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 370
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015021005453591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 371
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015021023163591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 372
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015021117172591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 373
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015030915161591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 374
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015031005054591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 375
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015031114281591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 376
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015031204030591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 377
# *******************************************
# ***mean_NO =  0.07518290598290599 ***
# ***mean_NO2 =  0.23934453781512605 ***
# ***mean_NOx =  0.23299999999999998 ***
# ANALYSING flight:  2015042014080591
# *******************************************
# ***Applying cuts***
# Mean NOx <xarray.DataArray ()>
# array(0.233)
# 75th percentile NOx 0.30874999999999997
# ***Calculating moving averages***
# ***Finding plumes***
# ***Removing planes***
# 0 plume(s) identified
# No plumes identified, end of anaylsis for this flight
# *******************************************
# IAGOS-CARIBIC 378
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2015042103395591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 379
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015042120424591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 380
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015042215563591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 381
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015051820290591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 382
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2015051919572591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 383
# *******************************************
# ***No NO2 recorded in this flight
# WARNING: NO2 all nan values in flight:  2015052010311591 , moving to next flight
# *******************************************
# IAGOS-CARIBIC 384
# *******************************************
# ***No NO recorded in this flight
# WARNING: NO all nan values in flight:  2015052100272591 , moving to next flight
# *******************************************
# IAGOS-CORE 385
# *******************************************
# WARNING: NO all nan values in flight:  2015052511085903 , moving to next flight
# *******************************************
# IAGOS-CORE 386
# *******************************************
# WARNING: NO all nan values in flight:  2015052523001903 , moving to next flight
# *******************************************
# IAGOS-CORE 387
# *******************************************
# WARNING: NO all nan values in flight:  2015052610223303 , moving to next flight
# *******************************************
# IAGOS-CORE 388
# *******************************************
# WARNING: NO all nan values in flight:  2015052621253603 , moving to next flight
# *******************************************
# IAGOS-CORE 389
# *******************************************
# ANALYSING flight:  2015052710344403
# *******************************************
# ***Applying cuts***
# Mean NOx <xarray.DataArray 'NOx_P2b' ()>
# array(0.53242083)
# 75th percentile NOx 0.7072499999999999
# ***Calculating moving averages***
# ***Finding plumes***
